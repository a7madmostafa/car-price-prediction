# %%
import pickle
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import RobustScaler, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OrdinalEncoder, FunctionTransformer, PolynomialFeatures
from category_encoders import BinaryEncoder
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor

# %%
# Load the unpreprocessed data
with open('../data/unprocessed_data.pkl', 'rb') as f:
    X_train, y_train, X_test, y_test = pickle.load(f)
    
X_train
# Out:
#        Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 5639       Pune  2006             155000    Petrol       Manual      Third
# 2303    Chennai  2006             109000    Petrol       Manual      First
# 2617     Jaipur  2008             128813    Diesel       Manual      First
# 1397      Kochi  2016              35659    Diesel    Automatic      First
# 3703      Delhi  2013              51000    Diesel    Automatic      First
# ...         ...   ...                ...       ...          ...        ...
# 3772    Chennai  2015              15000    Petrol    Automatic      First
# 5191  Hyderabad  2014              46000    Diesel       Manual     Second
# 5226  Bangalore  2012              73000    Diesel    Automatic      First
# 5390       Pune  2010              45252    Petrol       Manual      First
# 860     Kolkata  2011              98000    Diesel       Manual     Second
#
#       Mileage  Engine   Power  Seats       Brand   Model
# 5639    15.40  1590.0   94.00    5.0      Maruti  Baleno
# 2303    16.90  1497.0  100.00    5.0       Honda    City
# 2617    19.09  1396.0   69.00    5.0        Tata  Indigo
# 1397    15.97  2993.0  258.00    7.0         BMW      X5
# 3703    19.08  1582.0  126.32    5.0     Hyundai   Verna
# ...       ...     ...     ...    ...         ...     ...
# 3772    18.90  1197.0   82.00    5.0     Hyundai   Grand
# 5191    20.14  1498.0   88.80    5.0  Volkswagen    Polo
# 5226    22.69  1995.0  190.00    5.0         BMW       3
# 5390    18.90  1197.0   81.86    5.0     Hyundai   Grand
# 860     12.80  2494.0  102.00    8.0      Toyota  Innova
#
# [4812 rows x 12 columns]

# %%
# Load the preprocessed data
with open('../data/preprocessed_data.pkl', 'rb') as f:
    X_train_prep, y_train_log, X_test_prep, y_test_log = pickle.load(f)

X_train_prep
# Out:
# array([[ 1.66018158e-01,  4.99750125e-03, -4.74226804e-01, ...,
#          1.00000000e+00,  1.00000000e+00,  2.00600000e+03],
#        [ 4.53955901e-02,  1.04947526e-01, -2.16494845e-01, ...,
#          0.00000000e+00,  3.00000000e+00,  2.00600000e+03],
#        [-8.56031128e-02, -4.11460936e-01,  1.59793814e-01, ...,
#          1.00000000e+00,  3.00000000e+00,  2.00800000e+03],
#        ...,
#        [ 6.91309987e-01,  1.60419790e+00,  7.78350515e-01, ...,
#          0.00000000e+00,  3.00000000e+00,  2.01200000e+03],
#        [-3.43709468e-01, -1.97234716e-01,  1.27147766e-01, ...,
#          0.00000000e+00,  3.00000000e+00,  2.01000000e+03],
#        [ 1.33852140e+00,  1.38264201e-01, -9.20962199e-01, ...,
#          0.00000000e+00,  2.00000000e+00,  2.01100000e+03]])

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# Linear Regression
lr = LinearRegression()
lr.fit(X_train_prep, y_train_log)   # Learn Weights from training data Using OLS (Normal Equation)


lr_scores = cross_val_score(lr, X_train_prep, y_train_log, cv=5, scoring='r2')
print(f"Linear Regression: {np.mean(lr_scores)}")
# Out:
# Linear Regression: 0.8825006897659622

# %%
scores_dict = {'Linear Regression': round(np.mean(lr_scores), 2)}
scores_dict
# Out:
# {'Linear Regression': np.float64(0.88)}

# %% [markdown]
# # Polynomial Regression

# %%
#  Preprocessing & Base Model

num_cols_norm = ['Engine', 'Power', 'Mileage', 'Seats']  
num_cols_log = ['Kilometers_Driven']
nom_cat_cols = ['Location', 'Fuel_Type', 'Transmission', 'Brand', 'Model']
ord_cat_cols = ['Owner_Type']

imputer = SimpleImputer(strategy="median")
scaler  = RobustScaler()
bin_enc = BinaryEncoder()
ord_enc = OrdinalEncoder(categories=[['Fourth & Above', 'Third', 'Second', 'First']],
                         handle_unknown="use_encoded_value", unknown_value=-1)
poly = PolynomialFeatures(degree=2, include_bias=False)

log_transformer = FunctionTransformer(np.log1p, feature_names_out="one-to-one" )  

num_pipeline = Pipeline(steps=[ ('imputer', imputer),
                                ('poly', poly),
                                ('scaler', scaler)
                              ])
log_pipeline = Pipeline(steps=[ ('imputer', imputer),
                              ('log_transform', log_transformer),
                              ('poly', poly),
                              ('scaler', scaler)
                            ])
transformer = ColumnTransformer(transformers=[
                                                ('num', num_pipeline, num_cols_norm),
                                                ('log_transform', log_pipeline, num_cols_log),
                                                ('bin_enc', bin_enc, nom_cat_cols),
                                                ('ord_enc', ord_enc, ord_cat_cols)
                                            ], remainder='passthrough'
                                )


# Linear Regression
lr = LinearRegression()
pipe = Pipeline(steps=[ ('preprocessor', transformer),
                        ('model', lr)
                      ])


poly2_scores = cross_val_score(pipe, X_train, y_train_log, cv=5, scoring='r2')
print("Cross-validated R²: %.2f (± %.2f)" % (poly2_scores.mean(), poly2_scores.std() * 2))
# Out:
# Cross-validated R²: 0.90 (± 0.02)

# %%
scores_dict.update({'Polynomial Regression (2)': round(np.mean(poly2_scores), 2)})
scores_dict
# Out:
# {'Linear Regression': np.float64(0.88),
#  'Polynomial Regression (2)': np.float64(0.9)}

# %% [markdown]
# # Grid Search with Ridge Regression

# %%
# Grid Search with Ridge Regression (tuning alpha and polynomial degree)
ridge = Ridge()
pipe_ridge = Pipeline(steps=[ ('preprocessor', transformer),
                              ('model', ridge)
                            ])
param_grid = {
    'preprocessor__num__poly__degree': [1, 2, 3, 4],
    'model__alpha': [0.01, 0.1, 1.0, 10.0]
}
ridge_search = GridSearchCV(pipe_ridge, param_grid, cv=5, scoring='r2')
ridge_search.fit(X_train, y_train_log)
print("Best parameters:", ridge_search.best_params_)
print("Best cross-validated R²: %.2f" % ridge_search.best_score_)
# Out:
# Best parameters: {'model__alpha': 1.0, 'preprocessor__num__poly__degree': 3}
# Best cross-validated R²: 0.90

# %%
scores_dict.update({'Ridge Regression (3)': round(ridge_search.best_score_ , 2)})
scores_dict
# Out:
# {'Linear Regression': np.float64(0.88),
#  'Polynomial Regression (2)': np.float64(0.9),
#  'Ridge Regression (3)': np.float64(0.9)}

# %% [markdown]
# # Grid Search with Decision Tree

# %%
# Decision Tree
dt = DecisionTreeRegressor(random_state=42)
pipe_dt = Pipeline(steps=[ ('preprocessor', transformer),
                           ('model', dt)
                         ])
param_grid_dt = {
    'preprocessor__num__poly__degree': [1],
    'model__max_depth': [5, 10, 15, 20],
    'model__min_samples_split': [2, 5, 10],
    'model__min_samples_leaf': [1, 2, 4]
}
grid_search_dt = GridSearchCV(pipe_dt, param_grid_dt, cv=5, scoring='r2')
grid_search_dt.fit(X_train, y_train_log)
print("Best parameters:", grid_search_dt.best_params_)
print("Best cross-validated R²: %.2f" % grid_search_dt.best_score_)
# Out:
# Best parameters: {'model__max_depth': 10, 'model__min_samples_leaf': 4, 'model__min_samples_split': 2, 'preprocessor__num__poly__degree': 1}
# Best cross-validated R²: 0.90

# %%
scores_dict.update({'Decision Tree Regressor': round(grid_search_dt.best_score_, 2)})
scores_dict
# Out:
# {'Linear Regression': np.float64(0.88),
#  'Polynomial Regression (2)': np.float64(0.9),
#  'Ridge Regression (3)': np.float64(0.9),
#  'Decision Tree Regressor': np.float64(0.9)}

# %% [markdown]
# # Grid Search with RandomForest Regressor

# %%
# Random Forest
rf = RandomForestRegressor(random_state=42)
pipe_rf = Pipeline(steps=[ ('preprocessor', transformer),
                           ('model', rf)
                         ])
param_grid_rf = {
    'preprocessor__num__poly__degree': [1],
    'model__n_estimators': [100, 200],
    'model__max_depth': [10, 20],
    'model__min_samples_split': [2, 5],
    'model__min_samples_leaf': [1, 2]
}
grid_search_rf = GridSearchCV(pipe_rf, param_grid_dt, cv=5, scoring='r2')
grid_search_rf.fit(X_train, y_train_log)
print("Best parameters:", grid_search_rf.best_params_)
print("Best cross-validated R²: %.2f" % grid_search_rf.best_score_)
# Out:
# Best parameters: {'model__max_depth': 15, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'preprocessor__num__poly__degree': 1}
# Best cross-validated R²: 0.94

# %%
scores_dict.update({'RandomForest Regressor': round(grid_search_rf.best_score_, 2)})
scores_dict
# Out:
# {'Linear Regression': np.float64(0.88),
#  'Polynomial Regression (2)': np.float64(0.9),
#  'Ridge Regression (3)': np.float64(0.9),
#  'Decision Tree Regressor': np.float64(0.9),
#  'RandomForest Regressor': np.float64(0.94)}

# %% [markdown]
# # XGBoost

# %%
# XGBRegressor model
xgb = XGBRegressor(random_state=42, n_jobs=-1)

# Pipeline with preprocessing + model
pipe_xgb = Pipeline(steps=[
    ('preprocessor', transformer),
    ('model', xgb)
])

# Hyperparameter grid
param_grid_xgb = {
    'preprocessor__num__poly__degree': [1],   # keep same as your RF example
    'model__n_estimators': [100, 200, 500],
    'model__max_depth': [3, 5, 7],
    'model__learning_rate': [0.01, 0.05, 0.1],
    'model__subsample': [0.8, 1.0],
    'model__colsample_bytree': [0.8, 1.0],
    'model__gamma': [0, 0.1, 0.2]
}

# Grid search with 5-fold CV
grid_search_xgb = GridSearchCV(
    pipe_xgb,
    param_grid_xgb,
    cv=5,
    scoring='r2',
    n_jobs=-1,
    verbose=2
)

# Fit on log target if you're using y_train_log
grid_search_xgb.fit(X_train, y_train_log)

print("Best parameters:", grid_search_xgb.best_params_)
print("Best cross-validated R²: %.2f" % grid_search_xgb.best_score_)
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.5s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=5, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.8s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=5, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   1.0s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=5, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.9s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=5, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.8s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=5, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=5, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=5, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   1.0s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=5, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   1.0s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=5, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=5, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.8s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.5s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.5s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.8s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.8s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   1.6s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   1.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   1.8s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   2.0s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   1.8s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   2.6s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   2.5s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   1.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   1.8s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   1.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=3, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=3, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=3, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=3, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=3, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=3, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=3, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.5s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=3, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.6s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=3, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=3, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.6s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.6s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.6s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.8s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.9s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.5s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.5s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.6s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.8s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.8s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   1.5s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   1.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   1.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   1.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   1.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   1.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   1.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   1.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   1.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   1.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.5s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.6s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.6s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=5, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.8s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=5, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=5, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=5, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=5, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=5, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.7s
# [CV] END model__colsample_bytree=0.8, model__gamma=0, model__learning_rate=0.1, model__max_depth=5, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.7s
# ...
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.2s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.8s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.6s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   1.0s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=5, model__n_estimators=500, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=100, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=100, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=200, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.6s[CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
#
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=200, model__subsample=1.0, preprocessor__num__poly__degree=1; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.6s
# [CV] END model__colsample_bytree=1.0, model__gamma=0.2, model__learning_rate=0.05, model__max_depth=7, model__n_estimators=500, model__subsample=0.8, preprocessor__num__poly__degree=1; total time=   0.5s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 32
#      22 grid_search_xgb = GridSearchCV(
#      23     pipe_xgb,
#      24     param_grid_xgb,
#    (...)     28     verbose=2
#      29 )
#      31 # Fit on log target if you're using y_train_log
# ---> 32 grid_search_xgb.fit(X_train, y_train_log)
#      34 print("Best parameters:", grid_search_xgb.best_params_)
#      35 print("Best cross-validated R²: %.2f" % grid_search_xgb.best_score_)
#
# File /workspaces/car-price-prediction/car-price/lib/python3.11/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File /workspaces/car-price-prediction/car-price/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1051, in BaseSearchCV.fit(self, X, y, **params)
#    1045     results = self._format_results(
#    1046         all_candidate_params, n_splits, all_out, all_more_results
#    1047     )
#    1049     return results
# -> 1051 self._run_search(evaluate_candidates)
#    1053 # multimetric is determined here because in the case of a callable
#    1054 # self.scoring the return type is only known after calling
#    1055 first_test_score = all_out[0]["test_scores"]
#
# File /workspaces/car-price-prediction/car-price/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1605, in GridSearchCV._run_search(self, evaluate_candidates)
#    1603 def _run_search(self, evaluate_candidates):
#    1604     """Search all candidates in param_grid"""
# -> 1605     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File /workspaces/car-price-prediction/car-price/lib/python3.11/site-packages/sklearn/model_selection/_search.py:997, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     989 if self.verbose > 0:
#     990     print(
#     991         "Fitting {0} folds for each of {1} candidates,"
#     992         " totalling {2} fits".format(
#     993             n_splits, n_candidates, n_candidates * n_splits
#     994         )
#     995     )
# --> 997 out = parallel(
#     998     delayed(_fit_and_score)(
#     999         clone(base_estimator),
#    1000         X,
#    1001         y,
#    1002         train=train,
#    1003         test=test,
#    1004         parameters=parameters,
#    1005         split_progress=(split_idx, n_splits),
#    1006         candidate_progress=(cand_idx, n_candidates),
#    1007         **fit_and_score_kwargs,
#    1008     )
#    1009     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#    1010         enumerate(candidate_params),
#    1011         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#    1012     )
#    1013 )
#    1015 if len(out) < 1:
#    1016     raise ValueError(
#    1017         "No fits were performed. "
#    1018         "Was the CV iterator empty? "
#    1019         "Were there no candidates?"
#    1020     )
#
# File /workspaces/car-price-prediction/car-price/lib/python3.11/site-packages/sklearn/utils/parallel.py:82, in Parallel.__call__(self, iterable)
#      73 warning_filters = warnings.filters
#      74 iterable_with_config_and_warning_filters = (
#      75     (
#      76         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     80     for delayed_func, args, kwargs in iterable
#      81 )
# ---> 82 return super().__call__(iterable_with_config_and_warning_filters)
#
# File /workspaces/car-price-prediction/car-price/lib/python3.11/site-packages/joblib/parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File /workspaces/car-price-prediction/car-price/lib/python3.11/site-packages/joblib/parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File /workspaces/car-price-prediction/car-price/lib/python3.11/site-packages/joblib/parallel.py:1800, in Parallel._retrieve(self)
#    1789 if self.return_ordered:
#    1790     # Case ordered: wait for completion (or error) of the next job
#    1791     # that have been dispatched and not retrieved yet. If no job
#    (...)   1795     # control only have to be done on the amount of time the next
#    1796     # dispatched job is pending.
#    1797     if (nb_jobs == 0) or (
#    1798         self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799     ):
# -> 1800         time.sleep(0.01)
#    1801         continue
#    1803 elif nb_jobs == 0:
#    1804     # Case unordered: jobs are added to the list of jobs to
#    1805     # retrieve `self._jobs` only once completed or in error, which
#    (...)   1811     # timeouts before any other dispatched job has completed and
#    1812     # been added to `self._jobs` to be retrieved.
#
# KeyboardInterrupt:

# %%
# --- columns ---
km_col = 'Kilometers_Driven'
num_cols = ['Mileage','Engine','Power','Seats']          # numeric EXCLUDING km
nom_cat_cols = ['Location','Fuel_Type','Transmission','Brand','Model']
ord_cat_cols = ['Owner_Type']

# --- numeric (non-km) pipeline with toggleable scaler and poly ---
num_pipe = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('poly', PolynomialFeatures(include_bias=False)),   # degree will be set per model
    ('scaler', 'passthrough')                           # StandardScaler() for linear, passthrough for trees
])

# --- km pipeline: impute -> log1p -> (optional) scale ---
km_pipe = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('log', FunctionTransformer(np.log1p, feature_names_out='one-to-one')),
    ('scaler', 'passthrough')                           # StandardScaler() for linear, passthrough for trees
])

# --- categorical encoders ---
bin_enc = BinaryEncoder()
ord_enc = OrdinalEncoder(
    categories=[['Fourth & Above', 'Third', 'Second', 'First']],
    handle_unknown='use_encoded_value', unknown_value=-1
)

# --- unified preprocessor (scalers toggled via grid) ---
preprocessor = ColumnTransformer(transformers=[
    ('num', num_pipe, num_cols),
    ('km',  km_pipe,  [km_col]),
    ('bin', bin_enc,  nom_cat_cols),
    ('ord', ord_enc,  ord_cat_cols),
], remainder='drop')

# --- base pipeline (model placeholder) ---
pipe = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', LinearRegression())
])

# --- conditional param grids ---
param_grid = [
    # Linear models -> scale ON, poly degree 2–3
    {
        'model': [LinearRegression()],
        'preprocessor__num__poly__degree': [2, 3],
        'preprocessor__num__scaler': [StandardScaler()],
        'preprocessor__km__scaler': [StandardScaler()],
    },
    {
        'model': [Ridge(random_state=42)],
        'model__alpha': [0.1, 1.0, 10.0],
        'preprocessor__num__poly__degree': [2, 3],
        'preprocessor__num__scaler': [StandardScaler()],
        'preprocessor__km__scaler': [StandardScaler()],
    },

    # Tree/Ensemble models -> scale OFF, poly degree 1
    {
        'model': [RandomForestRegressor(random_state=42, n_jobs=-1)],
        'preprocessor__num__poly__degree': [1],
        'preprocessor__num__scaler': ['passthrough'],
        'preprocessor__km__scaler': ['passthrough'],
        'model__n_estimators': [200, 500],
        'model__max_depth': [10, 20, None],
        'model__min_samples_split': [2, 5],
        'model__min_samples_leaf': [1, 2],
    },
    {
        'model': [XGBRegressor(objective='reg:squarederror', random_state=42, n_jobs=-1)],
        'preprocessor__num__poly__degree': [1],
        'preprocessor__num__scaler': ['passthrough'],
        'preprocessor__km__scaler': ['passthrough'],
        'model__n_estimators': [200, 500],
        'model__max_depth': [3, 5, 7],
        'model__learning_rate': [0.01, 0.05, 0.1],
        'model__subsample': [0.8, 1.0],
        'model__colsample_bytree': [0.8, 1.0],
        'model__gamma': [0, 0.1, 0.2],
    },
]

grid = GridSearchCV(
    estimator=pipe,
    param_grid=param_grid,
    cv=5,
    scoring='r2',          # or 'neg_root_mean_squared_error'
    n_jobs=-1,
    verbose=1
)

grid.fit(X_train, y_train_log)

print("Best model:", type(grid.best_estimator_.named_steps['model']).__name__)
print("Best params:", grid.best_params_)
print("Best CV R²: %.3f" % grid.best_score_)
# Out:
# Fitting 5 folds for each of 248 candidates, totalling 1240 fits
# [CV] END model=LinearRegression(), preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=2, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=LinearRegression(), preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=2, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=LinearRegression(), preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=2, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=LinearRegression(), preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=2, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=LinearRegression(), preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=3, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=LinearRegression(), preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=2, preprocessor__num__scaler=StandardScaler(); total time=   0.2s
# [CV] END model=LinearRegression(), preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=3, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=LinearRegression(), preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=3, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=LinearRegression(), preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=3, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=LinearRegression(), preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=3, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=Ridge(random_state=42), model__alpha=0.1, preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=2, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=Ridge(random_state=42), model__alpha=0.1, preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=2, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=Ridge(random_state=42), model__alpha=0.1, preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=2, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=Ridge(random_state=42), model__alpha=0.1, preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=2, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=Ridge(random_state=42), model__alpha=0.1, preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=2, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=Ridge(random_state=42), model__alpha=0.1, preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=3, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=Ridge(random_state=42), model__alpha=0.1, preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=3, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=Ridge(random_state=42), model__alpha=0.1, preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=3, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=Ridge(random_state=42), model__alpha=0.1, preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=3, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=Ridge(random_state=42), model__alpha=1.0, preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=2, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=Ridge(random_state=42), model__alpha=0.1, preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=3, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=Ridge(random_state=42), model__alpha=1.0, preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=2, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=Ridge(random_state=42), model__alpha=1.0, preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=2, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=Ridge(random_state=42), model__alpha=1.0, preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=2, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=Ridge(random_state=42), model__alpha=1.0, preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=2, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=Ridge(random_state=42), model__alpha=1.0, preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=3, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=Ridge(random_state=42), model__alpha=1.0, preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=3, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=Ridge(random_state=42), model__alpha=1.0, preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=3, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=Ridge(random_state=42), model__alpha=1.0, preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=3, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=Ridge(random_state=42), model__alpha=1.0, preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=3, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=Ridge(random_state=42), model__alpha=10.0, preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=2, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=Ridge(random_state=42), model__alpha=10.0, preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=2, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=Ridge(random_state=42), model__alpha=10.0, preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=2, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=Ridge(random_state=42), model__alpha=10.0, preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=2, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=Ridge(random_state=42), model__alpha=10.0, preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=2, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=Ridge(random_state=42), model__alpha=10.0, preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=3, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=Ridge(random_state=42), model__alpha=10.0, preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=3, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=Ridge(random_state=42), model__alpha=10.0, preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=3, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=Ridge(random_state=42), model__alpha=10.0, preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=3, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=Ridge(random_state=42), model__alpha=10.0, preprocessor__km__scaler=StandardScaler(), preprocessor__num__poly__degree=3, preprocessor__num__scaler=StandardScaler(); total time=   0.1s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   3.5s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   3.5s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   3.4s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   3.5s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   3.5s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   8.6s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   8.8s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   8.6s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   8.4s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   3.5s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   8.5s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   3.4s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   3.7s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   3.5s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   3.6s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   8.2s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   8.1s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   8.0s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   8.1s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   3.8s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   8.8s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   4.3s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   5.5s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   4.7s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   3.4s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   8.4s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   8.1s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   8.4s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   8.7s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   3.4s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   8.2s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   3.2s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   3.3s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   4.0s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   3.9s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   8.7s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   8.3s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   8.2s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   7.7s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   5.3s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   8.0s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   5.6s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   5.4s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   5.7s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   5.3s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=  13.5s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=  13.0s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=  12.8s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=  13.0s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   4.5s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   4.3s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=  13.2s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   4.3s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   4.2s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   4.4s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=  10.6s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=  10.2s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=  10.4s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=  10.5s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   4.5s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   4.1s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=  10.4s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   4.6s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   4.0s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   4.3s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=  10.4s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=  10.3s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=  10.1s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=  10.6s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   4.0s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=  10.2s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   4.0s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   4.4s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   4.5s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   4.0s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=  10.2s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   9.6s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=  10.0s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=500, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=  10.5s
# [CV] END model=RandomForestRegressor(n_jobs=-1, random_state=42), model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__km__scaler=passthrough, preprocessor__num__poly__degree=1, preprocessor__num__scaler=passthrough; total time=   5.6s

# %% [markdown]
# # Final Model
